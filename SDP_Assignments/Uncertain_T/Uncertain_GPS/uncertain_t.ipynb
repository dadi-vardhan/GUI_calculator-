# %%
import numpy as np
import scipy.stats as st
import pandas as pd
from datetime import datetime
import time
import matplotlib.pyplot as plt

# %%
class Uncertain():
    def __init_(self,T):
        self.T = T
    
    def check_for_null(slef):
        pass

# %%
class Random_Primitive(Uncertain):
    def __init__(self,):
        pass
    def samples(self):
        pass

# %%
class Gaussain_T(Random_Primitive):
    def __init__(self,mu,std):
        self.mu = mu
        self.std = std
        self.num_samples = 100
        self.x_vals = np.linspace(min(T), max(T), 100)
        
    def get_samples(self):
        return np.random.normal(self.mu, self.std,self.num_samples)

    def gauss_pdf(self):
        return st.norm.pdf(self.x_vals, np.mean(T),np.std(T))

# %%
data = pd.read_csv("Uncertain_GPS/track_points.csv")
latitude = data['X'].to_list()
longitude = data['Y'].to_list()
time_data = data['time'].to_list()
time_sec=[]
for i in time_data:
    d=datetime.strptime(i[:-3], "%Y/%m/%d %H:%M:%S")
    time_sec.append(time.mktime(d.timetuple()))
latitude = [float(i) for i in latitude]
longitude= [float(i) for i in longitude]

plt.scatter(latitude,longitude)
plt.title("Route_map")
plt.xticks(np.linspace(np.min(latitude),np.max(latitude),10))
plt.yticks(np.linspace(np.min(longitude),np.max(longitude),10))
plt.show()
plt.hist(latitude,bins=50,density=True)
plt.title("Hist of Latitude")
y = np.linspace(min(latitude), max(latitude), 100)
plt.plot(y, st.norm.pdf(y,np.mean(latitude),np.std(latitude)),color="red")
plt.show()
plt.hist(latitude,bins=50,density=True)
plt.title("Hist of Latitude")
y = np.linspace(min(latitude), max(latitude), 100)
plt.plot(y, st.norm.pdf(y,np.mean(latitude),np.std(latitude)),color="red")
plt.show()
